# %%
%gnuplot inline svg

# %%
reset
# Out:
# >=>=

# %%
set xdata time
set timefmt "%Y-%m-%d"
set format x '%m-%d'
set datafile separator ","
plot "singapore.csv" u 2:5 title "Confirmed",\
     "singapore.csv" u 2:6 title "Deaths",\
     "singapore.csv" u 2:7 title "Recovered",\
     "singapore.csv" u 2:8 title "Active"
# Out:
# >=>=>=>=>=>=>=>=

# %%
set format x "%m/%d" timedate
set xtics 24*3600

y1 = NaN
plot "singapore.csv" u (timecolumn(2,"%Y-%m-%d")):(y0=y1,y1=$5,y1-y0) w lp pt 7 title "newly Confirmed"
# Out:
# >=>=>=>=>=>=>=
